# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('F:/Data Science/climate.csv')
df.shape
# Out:
# (1462, 5)

# %%
df.columns
# Out:
# Index(['date', 'meantemp', 'humidity', 'wind_speed', 'meanpressure'], dtype='object')

# %%
fig, ax = plt.subplots()
ax.scatter(df['meantemp'],df['humidity'])
ax.set_title('MeanTemp VS Humidity')
ax.set_ylabel('Humidity')
ax.set_xlabel('MeanTemp')
# Out:
# Text(0.5, 0, 'MeanTemp')

# %%
df1 = pd.DataFrame(data=df)
df1.corr(method='pearson')
# Out:
#               meantemp  humidity  wind_speed  meanpressure
# meantemp      1.000000 -0.571951    0.306468     -0.038818
# humidity     -0.571951  1.000000   -0.373972      0.001734
# wind_speed    0.306468 -0.373972    1.000000     -0.020670
# meanpressure -0.038818  0.001734   -0.020670      1.000000

# %%
fig, ax = plt.subplots()
ax.scatter(df['wind_speed'],df['humidity'])
ax.set_title('Wind_Speed VS Humidity')
ax.set_ylabel('Humidity')
ax.set_xlabel('Wind_Speed')
# Out:
# Text(0.5, 0, 'Wind_Speed')
