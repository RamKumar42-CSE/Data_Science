# %%
data = {
    "date":[1/1/2013,1/2/2013,1/3/2013,1/4/2013,1/5/2013,1/6/2013,1/7/2013,1/8/2013,1/9/2013,1/10/2013,1/11/2013,
1/12/2013,1/13/2013,1/14/2013,1/15/2013,1/16/2013,1/17/2013,1/18/2013,1/19/2013,1/20/2013,1/21/2013,1/22/2013,1/23/2013,1/24/2013,1/25/2013,1/26/2013,1/27/2013,1/28/2013,
1/29/2013,1/30/2013,1/31/2013,2/1/2013,2/2/2013,2/3/2013,2/4/2013,2/5/2013,2/6/2013,2/7/2013,2/8/2013,2/9/2013,2/10/2013,2/11/2013,2/12/2013,2/13/2013,2/14/2013,2/15/2013,
2/16/2013,2/17/2013,2/18/2013,2/19/2013],
    "meantemp":[10,7.4,7.166666667,8.666666667,6,7,7,8.857142857,14,11,15.71428571,14,15.83333333,12.83333333,14.71428571,13.83333333,16.5,
13.83333333,12.5,11.28571429,11.2,9.5,14,13.83333333,12.25,12.66666667,12.85714286,14.83333333,14.125,14.71428571,16.2,16,16.28571429,18,
17.42857143,16.625,16.66666667,15.6,14,15.42857143,15.25,15.875,15.33333333,16.28571429,17.33333333,19.16666667,14.42857143,13.66666667,15.6,15.85714286],
    "humidity":[84,92,87,71.33333333,86.83333333,82.8,78.6,63.71428571,51.25,62,51.28571429,74,75.16666667,88.16666667,71.85714286,
86.66666667,80.83333333,92.16666667,76.66666667,75.28571429,77,79.66666667,60.16666667,60.66666667,67,64.16666667,65.57142857,56,65.5,
70.42857143,65.6,73,77.57142857,65.57142857,74.28571429,92.375,71.33333333,59.4,70.42857143,61.28571429,71.5,70.5,70.33333333,70.14285714,63.83333333,65.33333333,92.71428571,90,78.4,82],
    "windspeed":[0,2.98,4.633333333,1.233333333,3.7,1.48,6.3,7.142857143,12.5,7.4,10.57142857,13.22857143,4.633333333,0.616666667,0.528571429,0,5.25,
8.95,5.883333333,8.471428571,2.22,3.083333333,4.016666667,6.166666667,5.55,6.8,5.557142857,3.7,3.2375,1.057142857,2.96,2.22,1.328571429,1.857142857,11.11428571,9.725,8.633333333,
10.74,9.257142857,9.257142857,3.475,5.325,7.416666667,6.085714286,4.333333333,10.18333333,8.485714286,0,12.22,5.814285714]
}

# %%
#Functions Used

#Length of data
l=len(data)
print("length=",l)

#Minimum of data
mi=min(data['meantemp'])
print("Minimum=",mi)

#Maximum of data
ma=max(data['meantemp'])
print("Maximum=",ma)

#Sort data
sor=sorted(data['humidity'])
print("Sorted=",sor)

#Data Type
t=type(data['windspeed'])
print("Type",t)
# Out:
# length= 4
# Minimum= 6
# Maximum= 19.16666667
# Sorted= [51.25, 51.28571429, 56, 59.4, 60.16666667, 60.66666667, 61.28571429, 62, 63.71428571, 63.83333333, 64.16666667, 65.33333333, 65.5, 65.57142857, 65.57142857, 65.6, 67, 70.14285714, 70.33333333, 70.42857143, 70.42857143, 70.5, 71.33333333, 71.33333333, 71.5, 71.85714286, 73, 74, 74.28571429, 75.16666667, 75.28571429, 76.66666667, 77, 77.57142857, 78.4, 78.6, 79.66666667, 80.83333333, 82, 82.8, 84, 86.66666667, 86.83333333, 87, 88.16666667, 90, 92, 92.16666667, 92.375, 92.71428571]
# Type <class 'list'>

# %%
#control Structure

#if statement
meantemp = 12.333
if meantemp > 10:
    print("High Temperature")
# Out:
# High Temperature

# %%
#if else
meantemp = 8
if meantemp > 10:
    print("High Temperature")
elif meantemp >= 7.5 and meantemp < 10:
    print("Average Temperature")
else:
    print("Low Temperature")
# Out:
# Average Temperature

# %%
#For Loop
print("For loop:")
for x in data['humidity']:
  print(x)
# Out:
# For loop:
# 84
# 92
# 87
# 71.33333333
# 86.83333333
# 82.8
# 78.6
# 63.71428571
# 51.25
# 62
# 51.28571429
# 74
# 75.16666667
# 88.16666667
# 71.85714286
# 86.66666667
# 80.83333333
# 92.16666667
# 76.66666667
# 75.28571429
# 77
# 79.66666667
# 60.16666667
# 60.66666667
# 67
# 64.16666667
# 65.57142857
# 56
# 65.5
# 70.42857143
# 65.6
# 73
# 77.57142857
# 65.57142857
# 74.28571429
# 92.375
# 71.33333333
# 59.4
# 70.42857143
# 61.28571429
# 71.5
# 70.5
# 70.33333333
# 70.14285714
# 63.83333333
# 65.33333333
# 92.71428571
# 90
# 78.4
# 82

# %%
#libraries used
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
