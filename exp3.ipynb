# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('F:/Data Science/climate.csv')
df.shape
# Out:
# (1462, 5)

# %%
##converting date variable to datetime 
df['date']=pd.to_datetime(df['date'])



##year
df['year']=df['date'].dt.year

##month in numeric
df['month']=df['date'].dt.month

## Month Name
df['Month Name']=df['date'].dt.month_name()

## Name of the day
df['Day Name']=df['date'].dt.day_name()

## Feature to identify Weekday and Weekend
df['Day of week']=['Weekend' if i in (['Saturday','Sunday']) else 'Weekday' for i in df['Day Name'] ]

df.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month  \
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1
#
#   Month Name   Day Name Day of week
# 0    January    Tuesday     Weekday
# 1    January  Wednesday     Weekday
# 2    January   Thursday     Weekday
# 3    January     Friday     Weekday
# 4    January   Saturday     Weekend

# %%
gb=df.groupby(['month','Month Name'])['meantemp'].mean().reset_index()
plt.figure(figsize=(15,8))
sns.barplot(x='Month Name',y='meantemp',data=gb);

# %%
df.hist(grid=False,figsize=(10,10))
plt.show()

# %%
df.meantemp.hist(grid=False, bins=10, )
plt.show()

# %%
Humidity = pd.Series(df.humidity)
print(Humidity.sort_values())
print(Humidity.max())
print(Humidity.min())
# Out:
# 856      13.428571
# 120      15.857143
# 1217     18.466667
# 140      19.000000
# 871      19.500000
#            ...
# 386      96.125000
# 731      96.625000
# 385      96.857143
# 921      98.000000
# 1461    100.000000
# Name: humidity, Length: 1462, dtype: float64
# 100.0
# 13.428571428571427

# %%
Humidity.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
meanpressure = pd.Series(df.meanpressure)
meanpressure
# Out:
# 0       1015.666667
# 1       1017.800000
# 2       1018.666667
# 3       1017.166667
# 4       1016.500000
#            ...
# 1457    1015.565217
# 1458    1016.904762
# 1459    1017.904762
# 1460    1016.100000
# 1461    1016.000000
# Name: meanpressure, Length: 1462, dtype: float64

# %%
sns.jointplot(df['humidity'],df['wind_speed'])
# Out:
# C:\Users\Ram\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
