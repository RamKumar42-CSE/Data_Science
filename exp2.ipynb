# %%
#Libraries used
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import data
df1=pd.read_csv('F:/Data Science/climate.csv')
df1.shape
# Out:
# (1462, 5)

# %%
#Remove null values
df=pd.read_csv('F:/Data Science/climate.csv',index_col=0)

# %%
#Describe Dataset
df.describe()
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %%
#dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 51.5+ KB

# %%
# datatype of attributes in csv
df.dtypes
# Out:
# date             object
# meantemp        float64
# humidity        float64
# wind_speed      float64
# meanpressure    float64
# dtype: object

# %%
#descriptive statistics and data summary
df.describe
# Out:
# <bound method NDFrame.describe of             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]>

# %%
#Reading Dataset
df.head(5)
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
# find any null values are present in data
df.isna().any()
# Out:
# date            False
# meantemp        False
# humidity        False
# wind_speed      False
# meanpressure    False
# dtype: bool

# %%
#array
arra = [df]
print(arra)
# Out:
# [            date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]]
# ('date', 'meantemp', 'humidity', 'wind_speed', 'meanpressure')

# %%
#Tuple
tuple(df)
# Out:
# ('date', 'meantemp', 'humidity', 'wind_speed', 'meanpressure')

# %%
#list
list(df)
# Out:
# ['date', 'meantemp', 'humidity', 'wind_speed', 'meanpressure']

# %%
tup = tuple(df['meantemp'])
for x in tup:
  print(x)
# Out:
# 10.0
# 7.4
# 7.166666666666668
# 8.666666666666666
# 6.0
# 7.0
# 7.0
# 8.857142857142858
# 14.0
# 11.0
# 15.714285714285715
# 14.0
# 15.833333333333336
# 12.833333333333336
# 14.714285714285715
# 13.833333333333336
# 16.5
# 13.833333333333336
# 12.5
# 11.285714285714285
# 11.2
# 9.5
# 14.0
# 13.833333333333336
# 12.25
# 12.666666666666664
# 12.857142857142858
# 14.833333333333336
# 14.125
# 14.714285714285715
# 16.2
# 16.0
# 16.285714285714285
# 18.0
# 17.428571428571427
# 16.625
# 16.666666666666668
# 15.6
# 14.0
# 15.428571428571427
# 15.25
# 15.875
# 15.333333333333336
# 16.285714285714285
# 17.333333333333332
# 19.166666666666668
# 14.428571428571427
# 13.666666666666664
# 15.6
# 15.857142857142858
# 17.714285714285715
# 20.0
# 20.5
# 17.428571428571427
# 16.857142857142858
# 16.875
# 17.857142857142858
# 20.8
# 19.428571428571427
# 17.333333333333332
# 19.0
# 19.33333333333333
# 17.6
# 20.875
# 20.857142857142858
# 23.42857142857143
# 24.16666666666667
# 25.42857142857143
# ...

# %%
list(df['meantemp'])
# Out:
# [10.0,
#  7.4,
#  7.166666666666668,
#  8.666666666666666,
#  6.0,
#  7.0,
#  7.0,
#  8.857142857142858,
#  14.0,
#  11.0,
#  15.714285714285715,
#  14.0,
#  15.833333333333336,
#  12.833333333333336,
#  14.714285714285715,
#  13.833333333333336,
#  16.5,
#  13.833333333333336,
#  12.5,
#  11.285714285714285,
#  11.2,
#  9.5,
#  14.0,
#  13.833333333333336,
#  12.25,
#  12.666666666666664,
#  12.857142857142858,
#  14.833333333333336,
#  14.125,
#  14.714285714285715,
#  16.2,
#  16.0,
#  16.285714285714285,
#  18.0,
#  17.428571428571427,
#  16.625,
#  16.666666666666668,
#  15.6,
#  14.0,
#  15.428571428571427,
#  15.25,
#  15.875,
#  15.333333333333336,
#  16.285714285714285,
#  17.333333333333332,
#  19.166666666666668,
#  14.428571428571427,
#  13.666666666666664,
#  15.6,
#  15.857142857142858,
#  17.714285714285715,
#  20.0,
#  20.5,
#  17.428571428571427,
#  16.857142857142858,
#  16.875,
#  17.857142857142858,
#  20.8,
#  19.428571428571427,
#  17.333333333333332,
#  19.0,
# ...

# %%
#Frequency tables
pd.crosstab(index=df['meantemp'],columns='count',dropna=True)
# Out:
# col_0      count
# meantemp
# 6.000000       1
# 7.000000       2
# 7.166667       1
# 7.400000       1
# 8.666667       1
# ...          ...
# 38.200000      1
# 38.272727      1
# 38.428571      1
# 38.500000      1
# 38.714286      1
#
# [617 rows x 1 columns]

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

print (df.describe())
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %%
Max_temp= df["meantemp"]
percentile10 = np.percentile(Max_temp, 10)

print(percentile10)
# Out:
# 14.625

# %%
humi= df["humidity"]
percentile10 = np.percentile(humi, 10)

print(percentile10)
# Out:
# 36.205000000000005

# %%
df['humidity'].plot(kind='box',title="Humidity")
print(df.quantile(.25))
print(df.quantile(.5))
print(df.quantile(.75))
# Out:
# meantemp          18.857143
# humidity          50.375000
# wind_speed         3.475000
# meanpressure    1001.580357
# Name: 0.25, dtype: float64
# meantemp          27.714286
# humidity          62.625000
# wind_speed         6.221667
# meanpressure    1008.563492
# Name: 0.5, dtype: float64
# meantemp          31.305804
# humidity          72.218750
# wind_speed         9.238235
# meanpressure    1014.944901
# Name: 0.75, dtype: float64
